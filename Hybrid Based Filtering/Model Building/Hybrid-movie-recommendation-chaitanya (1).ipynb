# %%
import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# %%
import numpy as np
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import linear_kernel
from surprise import Reader, Dataset, SVD
from surprise.model_selection import KFold
from surprise.model_selection.validation import cross_validate

# %%
hoo = pd.read_csv('/home/chaitanyadubal/Downloads/movies_metadata.csv')
hoo.head()
# Out:
# /tmp/ipykernel_111204/1721384356.py:1: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
#   hoo = pd.read_csv('/home/chaitanyadubal/Downloads/movies_metadata.csv')
#    adult                              belongs_to_collection    budget  \
# 0  False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1  False                                                NaN  65000000
# 2  False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3  False                                                NaN  16000000
# 4  False  {'id': 96871, 'name': 'Father of the Bride Col...         0
#
#                                               genres  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4                     [{'id': 35, 'name': 'Comedy'}]
#
# ...

# %%
ratings = pd.read_csv('/home/chaitanyadubal/Downloads/ratings_small.csv')
ratings.head()
# Out:
#    userId  movieId  rating   timestamp
# 0       1       31     2.5  1260759144
# 1       1     1029     3.0  1260759179
# 2       1     1061     3.0  1260759182
# 3       1     1129     2.0  1260759185
# 4       1     1172     4.0  1260759205

# %%
links = pd.read_csv('/home/chaitanyadubal/Downloads/links_small.csv')
links.head()
# Out:
#    movieId  imdbId   tmdbId
# 0        1  114709    862.0
# 1        2  113497   8844.0
# 2        3  113228  15602.0
# 3        4  114885  31357.0
# 4        5  113041  11862.0

# %%
keywords = pd.read_csv('/home/chaitanyadubal/Downloads/keywords.csv')
keywords.head()
# Out:
#       id                                           keywords
# 0    862  [{'id': 931, 'name': 'jealousy'}, {'id': 4290,...
# 1   8844  [{'id': 10090, 'name': 'board game'}, {'id': 1...
# 2  15602  [{'id': 1495, 'name': 'fishing'}, {'id': 12392...
# 3  31357  [{'id': 818, 'name': 'based on novel'}, {'id':...
# 4  11862  [{'id': 1009, 'name': 'baby'}, {'id': 1599, 'n...

# %%
credits = pd.read_csv('/home/chaitanyadubal/Downloads/credits.csv')
credits.head()
# Out:
#                                                 cast  \
# 0  [{'cast_id': 14, 'character': 'Woody (voice)',...
# 1  [{'cast_id': 1, 'character': 'Alan Parrish', '...
# 2  [{'cast_id': 2, 'character': 'Max Goldman', 'c...
# 3  [{'cast_id': 1, 'character': "Savannah 'Vannah...
# 4  [{'cast_id': 1, 'character': 'George Banks', '...
#
#                                                 crew     id
# 0  [{'credit_id': '52fe4284c3a36847f8024f49', 'de...    862
# 1  [{'credit_id': '52fe44bfc3a36847f80a7cd1', 'de...   8844
# 2  [{'credit_id': '52fe466a9251416c75077a89', 'de...  15602
# 3  [{'credit_id': '52fe44779251416c91011acb', 'de...  31357
# 4  [{'credit_id': '52fe44959251416c75039ed7', 'de...  11862

# %%
hoo['overview'] = hoo['overview'].fillna('')
hoo['overview'].head()
# Out:
# 0    Led by Woody, Andy's toys live happily in his ...
# 1    When siblings Judy and Peter discover an encha...
# 2    A family wedding reignites the ancient feud be...
# 3    Cheated on, mistreated and stepped on, the wom...
# 4    Just when George Banks has recovered from his ...
# Name: overview, dtype: object

# %%
pd.DataFrame({'feature':hoo.dtypes.index, 'dtype':hoo.dtypes.values})
# Out:
#                   feature    dtype
# 0                   adult   object
# 1   belongs_to_collection   object
# 2                  budget   object
# 3                  genres   object
# 4                homepage   object
# 5                      id   object
# 6                 imdb_id   object
# 7       original_language   object
# 8          original_title   object
# 9                overview   object
# 10             popularity   object
# 11            poster_path   object
# 12   production_companies   object
# 13   production_countries   object
# 14           release_date   object
# 15                revenue  float64
# 16                runtime  float64
# 17       spoken_languages   object
# 18                 status   object
# 19                tagline   object
# 20                  title   object
# 21                  video   object
# 22           vote_average  float64
# 23             vote_count  float64

# %%
hoo = hoo.drop([19730, 29503, 35587])

# %%
hoo['id'] = pd.to_numeric(hoo['id'])

# %%
pd.DataFrame({'feature':links.dtypes.index, 'dtype':links.dtypes.values})
# Out:
#    feature    dtype
# 0  movieId    int64
# 1   imdbId    int64
# 2   tmdbId  float64

# %%
col=np.array(links['tmdbId'], np.int64)
links['tmdbId']=col

# %%
hoo.rename(columns={'id':'tmdbId'}, inplace=True)
hoo = pd.merge(hoo,links,on='tmdbId')
hoo.drop(['imdb_id'], axis=1, inplace=True)
hoo.head()
# Out:
#    adult                              belongs_to_collection    budget  \
# 0  False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1  False                                                NaN  65000000
# 2  False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3  False                                                NaN  16000000
# 4  False  {'id': 96871, 'name': 'Father of the Bride Col...         0
#
#                                               genres  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4                     [{'id': 35, 'name': 'Comedy'}]
#
#                                homepage  tmdbId original_language  \
# 0  http://toystory.disney.com/toy-story     862                en
# 1                                   NaN    8844                en
# ...

# %%
tfidf = TfidfVectorizer(stop_words='english')

tfidf_matrix = tfidf.fit_transform(hoo['overview'])
tfidf_matrix.shape
# Out:
# (9099, 29727)

# %%
cosine_sim = linear_kernel(tfidf_matrix, tfidf_matrix)

indices = pd.Series(hoo.index, index=hoo['original_title']).drop_duplicates()

# %%
def recommend(title, cosine_sim=cosine_sim):
    
    
    idx = indices[title]
    
    sim_scores = list(enumerate(cosine_sim[idx]))
    
    sim_scores = sorted(sim_scores, key=lambda x: x[1], reverse=True)
    
    sim_scores = sim_scores[1:16]
    
    movie_indices = [i[0] for i in sim_scores]
    
    for i in movie_indices:
        pop = hoo.at[i,'vote_average']
        if pop<5 or pop>10:
            movie_indices.remove(i)

    
    return hoo[['original_title','vote_average']].iloc[movie_indices]

# %%
recommend('Iron Man')
# Out:
#                   original_title  vote_average
# 7516                  Iron Man 2           6.6
# 8296                  Iron Man 3           6.8
# 5670                    Scarface           7.5
# 8766     Avengers: Age of Ultron           7.3
# 8100                       Brake           5.3
# 4274        Saturday Night Fever           6.5
# 6063                     Hostage           6.2
# 2322               The Dark Half           5.4
# 6152               Batman Begins           7.5
# 1650  Return from Witch Mountain           5.6
# 5057     Dr. Jekyll and Mr. Hyde           6.6
# 1001               Touch of Evil           7.6
# 7183          Echelon Conspiracy           5.4
# 813     Escape to Witch Mountain           6.5
# 1774          Married to the Mob           5.8

# %%
reader = Reader() 
df = Dataset.load_from_df(ratings[['userId', 'movieId', 'rating']], reader)
kf = KFold(n_splits=5)
kf.split(df)
# Out:
# <generator object KFold.split at 0x7f240470fd80>

# %%
svd = SVD()
cross_validate(svd, df, measures=['RMSE', 'MAE'])

trainset = df.build_full_trainset()
svd.fit(trainset)

# %%
ratings[ratings['userId'] == 10]
# Out:
#      userId  movieId  rating  timestamp
# 744      10       50     5.0  942766420
# 745      10      152     4.0  942766793
# 746      10      318     4.0  942766515
# 747      10      344     3.0  942766603
# 748      10      345     4.0  942766603
# 749      10      592     3.0  942767328
# 750      10      735     4.0  942766974
# 751      10     1036     3.0  942767258
# 752      10     1089     3.0  942766420
# 753      10     1101     2.0  942767328
# 754      10     1127     4.0  942767328
# 755      10     1196     4.0  942767258
# 756      10     1197     4.0  942767258
# 757      10     1198     4.0  942767258
# 758      10     1200     4.0  942767258
# 759      10     1210     4.0  942767258
# 760      10     1220     3.0  942767328
# 761      10     1240     4.0  942767258
# 762      10     1291     4.0  942767258
# 763      10     1358     5.0  942766420
# 764      10     1423     4.0  942766420
# 765      10     1459     3.0  942766725
# ...

# %%
links_df = pd.read_csv('/home/chaitanyadubal/Downloads/links_small.csv')
col=np.array(links_df['tmdbId'], np.int64)
links_df['tmdbId']=col


links_df = links_df.merge(hoo[['title', 'tmdbId']], on='tmdbId').set_index('title')
links_index = links_df.set_index('tmdbId')

# %%
def hybrid(userId, title):
    idx = indices[title]
    tmdbId = links_df.loc[title]['tmdbId']
    
    sim_scores = list(enumerate(cosine_sim[idx]))
    sim_scores = sorted(sim_scores, key=lambda x: x[1], reverse=True)
    sim_scores = sim_scores[1:31] 
    movie_indices = [i[0] for i in sim_scores]
    
    movies = hoo.iloc[movie_indices][['title', 'vote_average', 'tmdbId']]
    movies['est'] = movies['tmdbId'].apply(lambda x: svd.predict(userId, links_index.loc[x]['movieId']).est)
    movies = movies.sort_values('est', ascending=False) 
    movies.columns = ['Title', 'Vote Average', 'TMDb Id', 'Estimated Prediction']
    return movies.head(15)

# %%
hybrid(1, 'The Conjuring')
# Out:
#                          Title  Vote Average  TMDb Id  Estimated Prediction
# 7795         Midnight in Paris           7.4    59436              3.402036
# 3784     Things Behind the Sun           5.9   102933              2.925547
# 9074           The Conjuring 2           7.0   259693              2.902871
# 8976                 Deathgasm           6.4   323373              2.796301
# 8262                Safe Haven           6.9   112949              2.795979
# 5364  Night of the Living Dead           6.7    19185              2.779343
# 3077      The Spiral Staircase           6.6    27452              2.746962
# 7049                 Magicians           6.2    10078              2.739551
# 6100     Electra Glide in Blue           6.6    26332              2.713822
# 8726           The Borderlands           5.1   207774              2.698631
# 5859           Shining Through           6.2    31962              2.685689
# ...

# %%
hybrid(30, 'Iron Man')
# Out:
#                            Title  Vote Average  TMDb Id  Estimated Prediction
# 8766     Avengers: Age of Ultron           7.3    99861              4.175429
# 1001               Touch of Evil           7.6     1480              4.086850
# 892        Rebel Without a Cause           7.6      221              4.048527
# 1650  Return from Witch Mountain           5.6    14822              3.949637
# 1503          All the King's Men           6.3    25430              3.905404
# 673                       Ransom           6.4     3595              3.900274
# 2640           To Sir, with Love           7.6    25934              3.895845
# 1774          Married to the Mob           5.8     2321              3.869715
# 5670                    Scarface           7.5      877              3.794872
# 3410                      Rififi           7.7      934              3.781151
# 3846                       Baran           7.6    43774              3.762544
# ...

# %%
from pickle import dump

dump(hybrid, open('/hybrid.pkl','wb'))
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# /tmp/ipykernel_111204/2129237699.py in <module>
#       1 from pickle import dump
#       2
# ----> 3 dump(hybrid, open('/hybrid.pkl','wb'))
#
# PermissionError: [Errno 13] Permission denied: '/hybrid.pkl'
